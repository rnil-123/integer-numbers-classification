# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# C:\Users\kunal.bharti\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2563 - accuracy: 0.9246
# Epoch 2/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1058 - accuracy: 0.9673
# Epoch 3/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0726 - accuracy: 0.9776
# Epoch 4/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0543 - accuracy: 0.9827
# Epoch 5/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0419 - accuracy: 0.9866
# Epoch 6/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0316 - accuracy: 0.9897
# Epoch 7/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0261 - accuracy: 0.9915
# Epoch 8/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0206 - accuracy: 0.9930
# Epoch 9/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0181 - accuracy: 0.9939
# Epoch 10/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0158 - accuracy: 0.9948
# Epoch 11/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0136 - accuracy: 0.9952
# Epoch 12/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0120 - accuracy: 0.9959
# Epoch 13/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0115 - accuracy: 0.9962
# Epoch 14/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0110 - accuracy: 0.9962
# Epoch 15/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0104 - accuracy: 0.9964
# Epoch 16/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0101 - accuracy: 0.9964
# Epoch 17/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0082 - accuracy: 0.9976
# Epoch 18/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0088 - accuracy: 0.9970
# Epoch 19/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0094 - accuracy: 0.9970
# Epoch 20/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0058 - accuracy: 0.9983
# Epoch 21/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0087 - accuracy: 0.9970
# Epoch 22/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0079 - accuracy: 0.9973
# Epoch 23/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0064 - accuracy: 0.9979
# Epoch 24/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0065 - accuracy: 0.9977
# Epoch 25/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0071 - accuracy: 0.9976
# Epoch 26/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0071 - accuracy: 0.9978
# Epoch 27/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0048 - accuracy: 0.9984
# Epoch 28/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0080 - accuracy: 0.9980
# Epoch 29/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0057 - accuracy: 0.9980
# Epoch 30/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0045 - accuracy: 0.9984
# Epoch 31/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0066 - accuracy: 0.9981
# Epoch 32/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0044 - accuracy: 0.9987
# Epoch 33/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 34/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0071 - accuracy: 0.9979
# Epoch 35/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9989
# Epoch 36/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 37/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 38/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 39/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 40/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 41/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 42/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0038 - accuracy: 0.9990
# Epoch 43/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0053 - accuracy: 0.9987
# Epoch 44/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0059 - accuracy: 0.9983
# Epoch 45/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 46/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0045 - accuracy: 0.9988
# Epoch 47/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 48/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9988
# Epoch 49/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0054 - accuracy: 0.9986
# Epoch 50/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0029 - accuracy: 0.9991

# %%
model.save('handwritten.model')
# Out:
# INFO:tensorflow:Assets written to: handwritten.model\assets

# %%
img = cv2.imread("C:/Users/kunal.bharti/Downloads/5_test.png")[:,:,0]
img = np.invert(np.array([img]))
prediction = model.predict(img)
print("This is probably - ", np.argmax(prediction))
# Out:
# 1/1 [==============================] - 0s 19ms/step
# This is probably -  7
